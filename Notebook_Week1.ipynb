# %% [markdown]
# # Capstone Project - The Battle of Neighbourhood

# %% [markdown]
# This Notebook has the project for the IBM Data Science Professional Certificate or Applied Data Science Capstone course on Coursera

# %% [markdown]
# ## Business Problem -

# %% [markdown]
# In this project we will try to find **how similar the two cities are** on the basis of the venues category or we can say **city's basic infrastructure** like parks, hotels, cafe's, etc. The two cities i have taken for this project are New Delhi and Mumbai.
#
# Since there will be a lot of venues in both cities we will restrict our venues to a limit of 100 and within 15km radius of the city.
#
# Specifically, this report will be helpful for a person or family who is **shifting for one cities to the other**. This report will help them determine how similar the city they are moving to is from the city they are currently living in.

# %% [markdown]
# ## A Little Brief on Cities -

# %% [markdown]
# <h2 align = "center">New Delhi</h2>

# %% [markdown]
# New Delhi is the capital of India and an administrative district of NCT Delhi. New Delhi is also the seat of all three branches of the Government of India, that is Executive (Rashtrapati Bhavan), Legislature (Parliament House) and Judiciary (Supreme Court of India).
#
# The foundation stone of New Delhi was laid by Emperor George V during the Delhi Durbar of 1911. It was designed by British architects Sir Edwin Lutyens and Sir Herbert Baker. The new capital was inaugurated on 13 February 1931, by Viceroy and Governor-General of India Lord Irwin.
#
# Although colloquially Delhi and New Delhi are used interchangeably to refer to the National Capital Territory of Delhi (NCT), these are two distinct entities, with New Delhi forming a small part of the city of Delhi. The National Capital Region is a much larger entity comprising the entire NCT along with adjoining districts in neighbouring states.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/49/Swaminarayan_Akshardham.jpg/1280px-Swaminarayan_Akshardham.jpg" width="200" align="right">
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/87/All_India_War_Memorial_%28INDIA_GATE%29.jpg/1280px-All_India_War_Memorial_%28INDIA_GATE%29.jpg" width="200" align="left">
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Lovely_Lotus_temple.jpg/1280px-Lovely_Lotus_temple.jpg" width="200" align="center">

# %% [markdown]
# <h2 align="center">Mumbai</h2>

# %% [markdown]
# Mumbai is the capital city of the Indian state of Maharashtra. According to the United Nations, as of 2018, Mumbai is the most populous city in the country and the seventh-most populous city in the world with a population of roughly 20 million.The city is also home to Bollywood and Marathi cinema industries.
#
# Mumbai lies on the Konkan coast on the west coast of India and has a deep natural harbour. In 2008, Mumbai was named an alpha world city. It has the highest number of millionaires and billionaires among all cities in India. Mumbai is home to three UNESCO World Heritage Sites: the Elephanta Caves, Chhatrapati Shivaji Maharaj Terminus, and the city's distinctive ensemble of Victorian and Art Deco buildings.
#
# Mumbai is the financial, commercial, and the entertainment capital of India. It is also one of the world's top ten centres of commerce in terms of global financial flow, generating 6.16% of India's GDP, and accounting for 25% of industrial output, 70% of maritime trade in India (Mumbai Port Trust and JNPT), and 70% of capital transactions to India's economy. Mumbai has the eighth-highest number of billionaires of any city in the world, and Mumbai's billionaires had the highest average wealth of any city in the world in 2008.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/2/2a/Chhatrapati_Shivaji_Maharaj_Terminal.jpg" width="200" align="right">
# <img src="https://upload.wikimedia.org/wikipedia/commons/d/d3/Gateway_of_India_-Mumbai.jpg" width="200" align="left">
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/14/Mumbai_Skyline_at_Night.jpg/1920px-Mumbai_Skyline_at_Night.jpg" width="200" align="center">

# %% [markdown]
# ## Data -

# %% [markdown]
# Based on defination of our Business Problem, factors that will influence our analysis are:
# * Number of Venues
# * Number of Unique Venue Categories
# * Frequency of Each Unique Venue Category
#
# Following data sources will be needed to extract/generate the required information:
# * Number of Venues and their category and location for each city will be obtained using **Foursquare API**
# * Coordinate of City center will be obtained using **Geopy Library**.

# %% [markdown]
# Let's Import some libraries we will be using for our analysis.

# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim

# %% [markdown]
# Let's first get the coordinated of both cities using the geopy library.

# %% [markdown]
# ### New Delhi's Coordinates

# %%
address_del = 'New Delhi, India'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address_del)
latitude_del = location.latitude
longitude_del = location.longitude
print('The geograpical coordinate of New Delhi are {}, {}.'.format(latitude_del, longitude_del))
# Out:
# The geograpical coordinate of New Delhi are 28.6138954, 77.2090057.

# %% [markdown]
# ### Mumbai's Coordinates

# %%
address_mum = 'Mumbai, Maharashtra'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address_mum)
latitude_mum = location.latitude
longitude_mum = location.longitude
print('The geograpical coordinate of Mumbai are {}, {}.'.format(latitude_mum, longitude_mum))
# Out:
# The geograpical coordinate of Mumbai are 18.9387711, 72.8353355.

# %% [markdown]
# Now we will get the rest of our data using Foursquare API.

# %% [markdown]
# ## FourSquare

# %% [markdown]
# First let's upload our credential for using the foursquare api.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Your credentails uploaded

# %% [markdown]
# We again import some libraries to help us with the process.

# %%
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %% [markdown]
# Now let's define a function that returns us the dataframe for the nearby popular venues, it's latitude, it's longitude and it's category for the given city.

# %%
def getNearbyVenues(lat,long,radius, Limit,city):# Function that returns the Dataframe for nearby popular venues for the given city
    
    venues_list = []
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            long, 
            radius, 
            Limit)
    
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    venues_list.append([(city, 
        v['venue']['name'], 
        v['venue']['location']['lat'], 
        v['venue']['location']['lng'],  
        v['venue']['categories'][0]['name']) for v in results])
        
    nearby_venues = 0
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = [ 'City',
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ## Delhi's Data

# %%
delhi_venues = getNearbyVenues(latitude_del, longitude_del,radius = 15000 , Limit = 100, city = 'New Delhi')
delhi_venues
# Out:
#          City                                              Venue  \
# 0   New Delhi                                              Tamra
# 1   New Delhi                                       The Imperial
# 2   New Delhi                                        Pandey Paan
# 3   New Delhi                                        Varq | वर्क
# 4   New Delhi                                 The Big Chill Cafe
# 5   New Delhi                                  Gulati Restaurant
# 6   New Delhi                    Gurudwara Sri Rakabganj Sahibji
# 7   New Delhi          Lodhi Gardens (लोधी बाग़) (Lodhi Gardens)
# 8   New Delhi                               SODABOTTLEOPENERWALA
# 9   New Delhi                                 Naturals Ice Cream
# 10  New Delhi            Khan Market | खान मार्केट (Khan Market)
# 11  New Delhi     Connaught Place | कनॉट प्लेस (Connaught Place)
# 12  New Delhi                                    Delhi Golf Club
# 13  New Delhi                         Perch, Wine And Coffee Bar
# 14  New Delhi                                       Amour Bistro
# 15  New Delhi                                           Wenger's
# 16  New Delhi                                      The Claridges
# 17  New Delhi                                         The Oberoi
# 18  New Delhi                              HOTEL SARAVANA BHAVAN
# 19  New Delhi  National Crafts Museum | राष्ट्रीय शिल्प संग्र...
# 20  New Delhi                                    The Lodhi Hotel
# 21  New Delhi                                  Spa At Shangri-La
# 22  New Delhi                                   The Leela Palace
# 23  New Delhi  Amar Jawan Jyoti | अमर जवान ज्योति (Amar Jawan...
# 24  New Delhi                                        Sagar Ratna
# 25  New Delhi                                            L'Opera
# 26  New Delhi                                      Indian Accent
# 27  New Delhi                                            Sevilla
# 28  New Delhi                                          Starbucks
# 29  New Delhi               India Gate | इंडिया गेट (India Gate)
# ..        ...                                                ...
# 70  New Delhi                                  Hauz Khas Village
# 71  New Delhi                                            Chaayos
# 72  New Delhi                  Jolly Creations Designer Boutique
# 73  New Delhi                                 Kunzum Travel Cafe
# 74  New Delhi  Sriram Centre For Art And Culture | श्रीराम कल...
# 75  New Delhi            Triveni Kala Sangam | त्रिवेणी कला संगम
# 76  New Delhi                                 The Big Chill Cafe
# 77  New Delhi                                  Haveli Dharampura
# 78  New Delhi                                      Indian Accent
# 79  New Delhi                                  Rajinder Da Dhaba
# 80  New Delhi                                        Bikanervala
# 81  New Delhi                                 The Drunkyard Cafe
# 82  New Delhi                               Amritsari Lassi Wala
# 83  New Delhi                                             Maxims
# 84  New Delhi                             Panchayat Paan Parlour
# 85  New Delhi                                                PCO
# 86  New Delhi             bloomrooms @ New Delhi Railway Station
# 87  New Delhi                                         Imperfecto
# 88  New Delhi                                            Nando's
# 89  New Delhi                                             Diggin
# 90  New Delhi                                          Naivedyam
# 91  New Delhi                                Hyatt Regency Delhi
# 92  New Delhi                      Defence colony flyover market
# 93  New Delhi                                       The Potbelly
# 94  New Delhi                                   South Campus, DU
# 95  New Delhi                                             Tamura
# 96  New Delhi                                          Le Cirque
# 97  New Delhi                                   Jaypee Siddharth
# 98  New Delhi                                         Coast Cafe
# 99  New Delhi                                    The Manor Hotel
#
#     Venue Latitude  Venue Longitude               Venue Category
# 0        28.620543        77.218174                   Restaurant
# 1        28.625548        77.218664                        Hotel
# 2        28.622249        77.201075                   Smoke Shop
# 3        28.604547        77.223781            Indian Restaurant
# 4        28.600686        77.227636           Italian Restaurant
# 5        28.608010        77.229989            Indian Restaurant
# 6        28.618296        77.205269             Spiritual Center
# 7        28.591424        77.220899                         Park
# 8        28.600141        77.226273                   Irani Cafe
# 9        28.634455        77.222139               Ice Cream Shop
# 10       28.600342        77.226923                       Market
# 11       28.632731        77.220018                        Plaza
# 12       28.599968        77.233288                  Golf Course
# 13       28.600058        77.226406                  Coffee Shop
# 14       28.601569        77.185923                         Café
# 15       28.633412        77.218292                       Bakery
# 16       28.600705        77.216601                        Hotel
# 17       28.596564        77.239634                        Hotel
# 18       28.627041        77.219514      South Indian Restaurant
# 19       28.613598        77.242039                   Art Museum
# 20       28.591669        77.238131                        Hotel
# 21       28.620869        77.218289                          Spa
# 22       28.579923        77.189291                        Hotel
# 23       28.612980        77.228247             Sculpture Garden
# 24       28.635487        77.220650            Indian Restaurant
# 25       28.599784        77.226144                         Café
# 26       28.592026        77.238006            Indian Restaurant
# 27       28.601144        77.216174     Mediterranean Restaurant
# 28       28.632011        77.217731                  Coffee Shop
# 29       28.612796        77.229207          Monument / Landmark
# ..             ...              ...                          ...
# 70       28.554311        77.195140                       Market
# 71       28.631629        77.220364                         Café
# 72       28.662689        77.226300                     Boutique
# 73       28.553684        77.194368                  Art Gallery
# 74       28.627069        77.233039                  Art Gallery
# 75       28.627278        77.232137                       Arcade
# 76       28.552728        77.241923           Italian Restaurant
# 77       28.653247        77.232309                        Hotel
# 78       28.570423        77.256753            Indian Restaurant
# 79       28.565268        77.199137            Indian Restaurant
# 80       28.570992        77.239132            Indian Restaurant
# 81       28.641451        77.215506           Tibetan Restaurant
# 82       28.657325        77.224138                  Snack Place
# 83       28.552849        77.242065                       Bakery
# 84       28.634073        77.222645            Indian Restaurant
# 85       28.561635        77.155590                    Speakeasy
# 86       28.645537        77.217701                        Hotel
# 87       28.554657        77.195092     Mediterranean Restaurant
# 88       28.630947        77.219721        Portuguese Restaurant
# 89       28.555665        77.218590                         Café
# 90       28.554987        77.195104      South Indian Restaurant
# 91       28.569264        77.185290                        Hotel
# 92       28.577555        77.238570                       Arcade
# 93       28.583796        77.187828  Northeast Indian Restaurant
# 94       28.583282        77.163769                   University
# 95       28.558154        77.206356          Japanese Restaurant
# 96       28.579758        77.189374            French Restaurant
# 97       28.642483        77.175543                        Hotel
# 98       28.554779        77.195214                         Café
# 99       28.570459        77.256791                        Hotel
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Mumbai's Data

# %%
mumbai_venues = getNearbyVenues(latitude_mum, longitude_mum,radius = 15000 , Limit = 100, city = 'Mumbai')
mumbai_venues
# Out:
#       City                                              Venue  Venue Latitude  \
# 0   Mumbai                                          Starbucks       18.932190
# 1   Mumbai                                   Wankhede Stadium       18.938792
# 2   Mumbai                                   Food for Thought       18.932031
# 3   Mumbai                        Natural's Ice Cream Parlour       18.934892
# 4   Mumbai                           Taj Mahal Palace & Tower       18.922306
# 5   Mumbai                                       Marine Drive       18.941221
# 6   Mumbai                                      Nariman Point       18.929183
# 7   Mumbai                               K Rustoms. Ice Cream       18.933478
# 8   Mumbai                                            Trishna       18.928619
# 9   Mumbai                                    The Sassy Spoon       18.928426
# 10  Mumbai                                    Britannia & Co.       18.934683
# 11  Mumbai                                     Yazdani Bakery       18.933191
# 12  Mumbai                               Jehangir Art Gallery       18.927606
# 13  Mumbai                                      Café Mondegar       18.924219
# 14  Mumbai     National Centre for the Performing Arts (NCPA)       18.925631
# 15  Mumbai                                   Queen's Necklace       18.933983
# 16  Mumbai                                        Royal China       18.938715
# 17  Mumbai                 Sea Lounge, Taj Mahal Palace Hotel       18.921503
# 18  Mumbai                                      Sher-E-Punjab       18.937944
# 19  Mumbai                             Shree Thaker Bhojnalay       18.951217
# 20  Mumbai                                            Trident       18.927878
# 21  Mumbai                                        Burma Burma       18.929590
# 22  Mumbai                                         Sabyasachi       18.926990
# 23  Mumbai                                       Tata Theatre       18.925063
# 24  Mumbai                                          Theobroma       18.919298
# 25  Mumbai  Chhatrapati Shivaji Maharaj Vastu Sangrahalaya...       18.926864
# 26  Mumbai                   The Bayview - Hotel Marine Plaza       18.931876
# 27  Mumbai                                               HQ's       18.925167
# 28  Mumbai                                          The Table       18.924099
# 29  Mumbai                                La Folie Patisserie       18.928504
# ..     ...                                                ...             ...
# 70  Mumbai                                          Ming Yang       19.043582
# 71  Mumbai                                       Five Gardens       19.019766
# 72  Mumbai                                Bandstand Promenade       19.046947
# 73  Mumbai                                          Elephanta       18.971931
# 74  Mumbai                                            Candies       19.049709
# 75  Mumbai                                      Jogger's Park       19.059728
# 76  Mumbai                                        Indigo Deli       19.061710
# 77  Mumbai                                            Candies       19.061176
# 78  Mumbai                                    Mehboob Studios       19.052332
# 79  Mumbai                                            Escobar       19.060177
# 80  Mumbai                           Starbucks Coffee Capital       19.063457
# 81  Mumbai                  Punjab Sweet House And Restaurant       19.062553
# 82  Mumbai                            Chocolateria San Churro       19.061918
# 83  Mumbai                                   Bombay Salad Co.       19.064715
# 84  Mumbai                                        Pali Bhavan       19.062089
# 85  Mumbai                                Bombay Coffee House       19.063425
# 86  Mumbai                                          Mac Craig       19.061542
# 87  Mumbai                                   Smoke House Deli       19.065482
# 88  Mumbai                                           MCA Club       19.060443
# 89  Mumbai                                            Candies       19.070288
# 90  Mumbai                                            Suzette       19.061526
# 91  Mumbai                         Blue Tokai Coffee Roasters       19.060480
# 92  Mumbai                       Chembur Post Office Wada Pav       19.056940
# 93  Mumbai                              Carter Road Promenade       19.067250
# 94  Mumbai                                            Hitchki       19.069730
# 95  Mumbai                                  Natural Ice Cream       19.052643
# 96  Mumbai                                        Pali Market       19.062741
# 97  Mumbai                                     Lamba Da Dhaba       19.052602
# 98  Mumbai                                     The Bagel Shop       19.063140
# 99  Mumbai                             Spatika - Spa & Saloon       19.055858
#
#     Venue Longitude           Venue Category
# 0         72.833959              Coffee Shop
# 1         72.825944           Cricket Ground
# 2         72.831667                     Café
# 3         72.824222           Ice Cream Shop
# 4         72.833578                    Hotel
# 5         72.823261           Scenic Lookout
# 6         72.822232           Scenic Lookout
# 7         72.824995           Ice Cream Shop
# 8         72.832356       Seafood Restaurant
# 9         72.822512                    Diner
# 10        72.840183         Parsi Restaurant
# 11        72.833591                   Bakery
# 12        72.831464              Art Gallery
# 13        72.832106                     Café
# 14        72.819861    Performing Arts Venue
# 15        72.823896                    Beach
# 16        72.832933       Chinese Restaurant
# 17        72.833298                   Lounge
# 18        72.837853        Indian Restaurant
# 19        72.828326        Indian Restaurant
# 20        72.820711                    Hotel
# 21        72.832043         Asian Restaurant
# 22        72.833185                 Boutique
# 23        72.819958                  Theater
# 24        72.829185             Dessert Shop
# 25        72.832559           History Museum
# 26        72.823031       Italian Restaurant
# 27        72.832051                Nightclub
# 28        72.833097  New American Restaurant
# 29        72.832315             Dessert Shop
# ..              ...                      ...
# 70        72.819199       Chinese Restaurant
# 71        72.853818                   Garden
# 72        72.819915           Scenic Lookout
# 73        72.930505            Historic Site
# 74        72.829785               Restaurant
# 75        72.822055                     Park
# 76        72.829972            Deli / Bodega
# 77        72.826634                   Bakery
# 78        72.824992    Performing Arts Venue
# 79        72.836446                   Lounge
# 80        72.861576              Coffee Shop
# 81        72.829423        Indian Restaurant
# 82        72.834480             Dessert Shop
# 83        72.830920              Salad Place
# 84        72.829459        Indian Restaurant
# 85        72.834671                     Café
# 86        72.828894                   Bakery
# 87        72.829861            Deli / Bodega
# 88        72.866020                 Gym Pool
# 89        72.826245     Fast Food Restaurant
# 90        72.829081        French Restaurant
# 91        72.824320                     Café
# 92        72.898056              Snack Place
# 93        72.822915           Scenic Lookout
# 94        72.869761                      Bar
# 95        72.899760             Dessert Shop
# 96        72.828336           Farmers Market
# 97        72.899391       Punjabi Restaurant
# 98        72.824902               Bagel Shop
# 99        72.900428                      Spa
#
# [100 rows x 5 columns]

# %% [markdown]
# Looking good. So now we have all the popular venues in area within 15km from both the cities.
#
# This concludes the data gathering phase - we're now ready to use this data for analysis to produce the report on similarity of both the cities!
