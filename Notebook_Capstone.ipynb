# %% [markdown]
# # Capstone Project

# %% [markdown]
# This Notebook will contain the capstone project of the IBM Data Science Professional Certificate or Applied Data Science Specialization on Coursera.
# So what we will learn to do in this project is given a city like the City of Toronto, we will segment it into different neighborhoods using the geographical coordinates of the center of each neighborhood, and then using a combination of location data and machine learning, we will group the neighbourhoods into clusters.

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
